# %%
import matplotlib.pyplot as plt

plt.bar(df["country"], df["value"])
plt.title("Environment Test")
plt.xlabel("Country")
plt.ylabel("Value")
plt.show()

# %%
df = pd.DataFrame({
    "country": ["Brazil", "Chile", "Mexico"],
    "value": [10, 20, 30]
})

df
# Out:
#   country  value
# 0  Brazil     10
# 1   Chile     20
# 2  Mexico     30

# %%
import sys

import numpy as np
import pandas as pd

print("Notebook environment working correctly.")
print("Python:", sys.version.split()[0])
print("Executable:", sys.executable)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Notebook environment working correctly.
# Python: 3.12.10
# Executable: c:\Users\vitor\Documents\Portfolio\portfolio-setup\.venv\Scripts\python.exe
# Pandas: 3.0.5
# NumPy: 2.5.3
